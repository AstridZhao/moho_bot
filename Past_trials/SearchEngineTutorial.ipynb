# %% [markdown]
# # Building a simple command line search engine
#
# ### In this tutorial, we'll build a simple search engine using the nltk, pandas, and BeautifulSoup4 modules.  These modules contain many tools and utilities that you may find useful for your final project.
# - nltk (natural language tool kit) is a platform for processing and analyzing human language data.  It also contains many corpora and lexical resources such as WordNet.
# - pandas is the python data analysis library that we explored on Tuesday
# - Beautiful Soup is a package for parsing HTML and XML documents.  It creates a parse tree that can be used to extract data from the parsed pages.
#
# ## Step 1 Parsing the corpus
#
# ### Our sample corpus contains 7 news articles from the ap89 collection (Associated Press, 1989). We use the BeautifulSoup4 module to parse our documents.

# %%
# import the bs module
from bs4 import BeautifulSoup

''' tokenize and casefold'''
def tokenizeAndCasefold (text):
    text = text.lower()
    tokens = text.split()
    return tokens

# open sgml file of documents

### replace /home/jupyter-lballest with the name of your home directory
#file = '/home/jupyter-lballest/COMSC_243_shared/ap.sample.txt'
file = '/home/jupyter-lballest/COMSC-341TE/ap89.sample.txt'
fp = open(file,'r')

# read as one long string.  Note this is not a good approach since a larger file
# will need to be read a line at a time to avoid memory problems
text = fp.read()

# parse with html (similar to SGML) parser which returns a tree structure
# containing our parsed document data
# each sgml tag will be a node in the tree, each 'doc' tag a sub-tree
soup = BeautifulSoup(text, 'html.parser')

# can use tags to access specific objects of each doc in the tree
# tags we care about are 'doc', 'head', and 'text'
# we can access the text of those objects using the .text member

# we'll place the text of each doc in a list and append to one large list
collectionText = []

# iterate on the 'doc' nodes of the tree
for doc in soup('doc'):
    # initialize string to collect document headlines and text
    bodyText = ""
    # get the text nodes of each doc tag and save the text associated with that tag
    # iterate on each text tag
    for body in doc.find_all('text'):
        bodyText += body.text
        bodyText += ' '    
    # tokenize and lowercase the text
    bodyTokens = tokenizeAndCasefold(bodyText)
    collectionText.append(bodyTokens)
print(collectionText)
# Out:
# [['the', 'celluloid', 'torch', 'has', 'been', 'passed', 'to', 'a', 'new', 'generation:', 'filmmakers', 'who', 'grew', 'up', 'in', 'the', '1960s.', "``platoon,''", '``running', 'on', "empty,''", "``1969''", 'and', '``mississippi', "burning''", 'are', 'among', 'the', 'movies', 'released', 'in', 'the', 'past', 'two', 'years', 'from', 'writers', 'and', 'directors', 'who', 'brought', 'their', 'own', 'experiences', 'of', 'that', 'turbulent', 'decade', 'to', 'the', 'screen.', '``the', 'contemporaries', 'of', 'the', "'60s", 'are', 'some', 'of', 'the', 'filmmakers', 'of', 'the', "'80s.", "it's", "natural,''", 'said', 'robert', 'friedman,', 'the', 'senior', 'vice', 'president', 'of', 'worldwide', 'advertising', 'and', 'publicity', 'at', 'warner', 'bros.', 'chris', 'gerolmo,', 'who', 'wrote', 'the', 'screenplay', 'for', '``mississippi', "burning,''", 'noted', 'that', 'the', 'sheer', 'passage', 'of', 'time', 'has', 'allowed', 'him', 'and', 'others', 'to', 'express', 'their', 'feelings', 'about', 'the', 'decade.', '``distance', 'is', "important,''", 'he', 'said.', '``i', 'believe', "there's", 'a', 'lot', 'of', 'thinking', 'about', 'that', 'time', 'and', 'america', 'in', "general.''", 'the', 'vietnam', 'war', 'was', 'a', 'defining', 'experience', 'for', 'many', 'people', 'in', 'the', "'60s,", 'shattering', 'the', 'consensus', 'that', 'the', 'united', 'states', 'had', 'a', 'right,', 'even', 'a', 'moral', 'duty', 'to', 'intervene', 'in', 'conflicts', 'around', 'the', 'world.', 'even', 'today,', 'politicians', 'talk', 'disparagingly', 'of', 'the', '``vietnam', "syndrome''", 'in', 'referring', 'to', 'the', "country's", 'reluctance', 'to', 'use', 'military', 'force', 'to', 'settle', 'disputes.', '``i', 'think', 'future', 'historians', 'will', 'talk', 'about', 'vietnam', 'as', 'one', 'of', 'the', 'near', 'destructions', 'of', 'american', "society,''", 'said', 'urie', 'brofenbrenner,', 'a', 'professor', 'of', 'sociology', 'at', 'cornell', 'university.', '``in', 'world', 'war', 'ii,', 'we', 'knew', 'what', 'we', 'were', 'fighting', 'for,', 'but', 'not', 'in', "vietnam.''", '``full', 'metal', "jacket,''", '``gardens', 'of', "stone,''", "``platoon,''", '``good', 'morning,', "vietnam,''", '``hamburger', "hill''", 'and', '``bat', "21''", 'all', 'use', 'the', 'war', 'as', 'a', 'dramatic', 'backdrop', 'and', 'show', 'how', 'it', 'shaped', "characters'", 'lives.', 'the', 'vietnam', 'war', 'has', 'remained', 'an', 'emotional', 'issue', 'in', 'the', 'united', 'states', 'as', 'veterans', 'have', 'struggled', 'to', 'come', 'to', 'terms', 'with', 'their', 'experiences.', 'one', 'was', 'oliver', 'stone,', 'who', 'wrote', 'and', 'directed', 'the', 'academy', 'award-winning', "``platoon.''", '``i', 'saw', "`platoon'", 'eight', "times,''", 'said', 'john', 'j.', 'anderson,', 'a', 'palm', 'beach', 'county', "sheriff's", 'lieutenant', 'who', 'served', 'in', 'vietnam', 'in', '1966-67.', '``i', 'cried', 'the', 'first', 'time', 'i', 'saw', 'it', '...', 'and', 'the', 'third', 'and', 'fourth', 'times.', "`platoon'", 'helped', 'me', "understand.''", 'stone,', 'who', 'based', "``platoon''", 'on', 'some', 'of', 'his', 'own', 'experiences', 'as', 'a', 'grunt,', 'said', 'the', 'film', 'brought', 'up', 'issues', 'that', 'had', 'yet', 'to', 'be', 'resolved.', '``people', 'are', 'responding', 'to', 'the', 'fact', 'that', "it's", 'real.', "they're", 'curious', 'about', 'the', 'war', 'in', 'vietnam', 'after', '20', "years,''", 'he', 'said.', 'while', 'southeast', 'asia', 'was', 'the', 'pivotal', 'foreign', 'issue', 'in', 'american', 'society', 'of', 'the', "'60s,", 'civil', 'rights', 'was', 'the', 'major', 'domestic', 'issue.', 'the', 'civil', 'rights', 'movement', 'reached', 'its', 'peak', 'in', 'the', '``freedom', "summer''", 'of', '1964,', 'when', 'large', 'groups', 'of', 'volunteers', 'headed', 'south', 'to', 'help', 'register', 'black', 'voters.', 'in', '``five', "corners,''", 'a', 'movie', 'about', 'the', 'summer', 'of', "'64", 'in', 'the', 'bronx', 'starring', 'jodie', 'fost ...

# %% [markdown]
# ### Notice that the text displayed above contains hyphens.   Lets replace them with white space.

# %%
import string
#create a table that will replace the dash with white space, nothing is deleted
dashTable = str.maketrans('-',' ','')

# create a list to store lists containing the text for each document 
# (each inner list corresponds to one document)
docTexts = []
# iterate on the 'doc' nodes of the tree
# iterate on the 'doc' nodes of the tree
for doc in soup('doc'):
    # initialize string to collect document text
    bodyText = ""
    # get the text nodes of each doc tag and save the text associated with that tag
    # iterate on each text tag
    for body in doc.find_all('text'):
        bodyText += body.text
        bodyText += ' '    
    bodyText = bodyText.translate(dashTable)
    # tokenize and lowercase the text
    bodyTokens = tokenizeAndCasefold(bodyText)
    # append this text free of hyphenated words to the list of document texts
    docTexts.append(bodyTokens)
print(docTexts)
# Out:
# [['the', 'celluloid', 'torch', 'has', 'been', 'passed', 'to', 'a', 'new', 'generation:', 'filmmakers', 'who', 'grew', 'up', 'in', 'the', '1960s.', "``platoon,''", '``running', 'on', "empty,''", "``1969''", 'and', '``mississippi', "burning''", 'are', 'among', 'the', 'movies', 'released', 'in', 'the', 'past', 'two', 'years', 'from', 'writers', 'and', 'directors', 'who', 'brought', 'their', 'own', 'experiences', 'of', 'that', 'turbulent', 'decade', 'to', 'the', 'screen.', '``the', 'contemporaries', 'of', 'the', "'60s", 'are', 'some', 'of', 'the', 'filmmakers', 'of', 'the', "'80s.", "it's", "natural,''", 'said', 'robert', 'friedman,', 'the', 'senior', 'vice', 'president', 'of', 'worldwide', 'advertising', 'and', 'publicity', 'at', 'warner', 'bros.', 'chris', 'gerolmo,', 'who', 'wrote', 'the', 'screenplay', 'for', '``mississippi', "burning,''", 'noted', 'that', 'the', 'sheer', 'passage', 'of', 'time', 'has', 'allowed', 'him', 'and', 'others', 'to', 'express', 'their', 'feelings', 'about', 'the', 'decade.', '``distance', 'is', "important,''", 'he', 'said.', '``i', 'believe', "there's", 'a', 'lot', 'of', 'thinking', 'about', 'that', 'time', 'and', 'america', 'in', "general.''", 'the', 'vietnam', 'war', 'was', 'a', 'defining', 'experience', 'for', 'many', 'people', 'in', 'the', "'60s,", 'shattering', 'the', 'consensus', 'that', 'the', 'united', 'states', 'had', 'a', 'right,', 'even', 'a', 'moral', 'duty', 'to', 'intervene', 'in', 'conflicts', 'around', 'the', 'world.', 'even', 'today,', 'politicians', 'talk', 'disparagingly', 'of', 'the', '``vietnam', "syndrome''", 'in', 'referring', 'to', 'the', "country's", 'reluctance', 'to', 'use', 'military', 'force', 'to', 'settle', 'disputes.', '``i', 'think', 'future', 'historians', 'will', 'talk', 'about', 'vietnam', 'as', 'one', 'of', 'the', 'near', 'destructions', 'of', 'american', "society,''", 'said', 'urie', 'brofenbrenner,', 'a', 'professor', 'of', 'sociology', 'at', 'cornell', 'university.', '``in', 'world', 'war', 'ii,', 'we', 'knew', 'what', 'we', 'were', 'fighting', 'for,', 'but', 'not', 'in', "vietnam.''", '``full', 'metal', "jacket,''", '``gardens', 'of', "stone,''", "``platoon,''", '``good', 'morning,', "vietnam,''", '``hamburger', "hill''", 'and', '``bat', "21''", 'all', 'use', 'the', 'war', 'as', 'a', 'dramatic', 'backdrop', 'and', 'show', 'how', 'it', 'shaped', "characters'", 'lives.', 'the', 'vietnam', 'war', 'has', 'remained', 'an', 'emotional', 'issue', 'in', 'the', 'united', 'states', 'as', 'veterans', 'have', 'struggled', 'to', 'come', 'to', 'terms', 'with', 'their', 'experiences.', 'one', 'was', 'oliver', 'stone,', 'who', 'wrote', 'and', 'directed', 'the', 'academy', 'award', 'winning', "``platoon.''", '``i', 'saw', "`platoon'", 'eight', "times,''", 'said', 'john', 'j.', 'anderson,', 'a', 'palm', 'beach', 'county', "sheriff's", 'lieutenant', 'who', 'served', 'in', 'vietnam', 'in', '1966', '67.', '``i', 'cried', 'the', 'first', 'time', 'i', 'saw', 'it', '...', 'and', 'the', 'third', 'and', 'fourth', 'times.', "`platoon'", 'helped', 'me', "understand.''", 'stone,', 'who', 'based', "``platoon''", 'on', 'some', 'of', 'his', 'own', 'experiences', 'as', 'a', 'grunt,', 'said', 'the', 'film', 'brought', 'up', 'issues', 'that', 'had', 'yet', 'to', 'be', 'resolved.', '``people', 'are', 'responding', 'to', 'the', 'fact', 'that', "it's", 'real.', "they're", 'curious', 'about', 'the', 'war', 'in', 'vietnam', 'after', '20', "years,''", 'he', 'said.', 'while', 'southeast', 'asia', 'was', 'the', 'pivotal', 'foreign', 'issue', 'in', 'american', 'society', 'of', 'the', "'60s,", 'civil', 'rights', 'was', 'the', 'major', 'domestic', 'issue.', 'the', 'civil', 'rights', 'movement', 'reached', 'its', 'peak', 'in', 'the', '``freedom', "summer''", 'of', '1964,', 'when', 'large', 'groups', 'of', 'volunteers', 'headed', 'south', 'to', 'help', 'register', 'black', 'voters.', 'in', '``five', "corners,''", 'a', 'movie', 'about', 'the', 'summer', 'of', "'64", 'in', 'the', 'bronx', 'starring', 'jodie', ...

# %% [markdown]
# ###   There are still some token definitions we may want to change e.g. some tokens contain '.' or apostrophy characters. nltk has a more sophisticated tokenizer that we can use.  In order to do so, we have to download its parameters.

# %%
import nltk
nltk.download("punkt")
# Out:
# [nltk_data] Downloading package punkt to /home/jupyter-
# [nltk_data]     lballest/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# create a list to store lists containing the text tokens for each document 
# (each inner list corresponds to one document)
docsTextTokens = []
# create a list to store lists containing the text for each document 
# (each inner list corresponds to one document)
docTexts = []
# iterate on the 'doc' nodes of the tree
# iterate on the 'doc' nodes of the tree
for doc in soup('doc'):
    # initialize string to collect document text
    bodyText = ""
    # get the text nodes of each doc tag and save the text associated with that tag
    # iterate on each text tag
    for body in doc.find_all('text'):
        bodyText += body.text
        bodyText += ' '    
    bodyText = bodyText.translate(dashTable)
    docTexts.append(bodyText)
# iterate on the document texts
for theText in docTexts:
    # tokenize the text
    tokens = nltk.word_tokenize(theText)
    # append this new list of words
    docsTextTokens.append(tokens)
  #  print(tokens)
print(docsTextTokens)
# Out:
# [['The', 'celluloid', 'torch', 'has', 'been', 'passed', 'to', 'a', 'new', 'generation', ':', 'filmmakers', 'who', 'grew', 'up', 'in', 'the', '1960s', '.', '``', 'Platoon', ',', "''", '``', 'Running', 'on', 'Empty', ',', "''", '``', '1969', "''", 'and', '``', 'Mississippi', 'Burning', "''", 'are', 'among', 'the', 'movies', 'released', 'in', 'the', 'past', 'two', 'years', 'from', 'writers', 'and', 'directors', 'who', 'brought', 'their', 'own', 'experiences', 'of', 'that', 'turbulent', 'decade', 'to', 'the', 
'`', 'Platoon', "'", 'helped', 'me', 'understand', '.', "''", 'Stone', ',', 'who', 'based', '``', 'Platoon', "''", 'on', 'some', 'of', 'his', 'own', 'experiences', 'as', 'a', 'grunt', ',', 'said', 'the', 'film', 'brought', 'up', 'issues', 'that', 'had', 'yet', 'to', 'be', 'resolved', '.', '``', 'People', 'are', 'responding', 'to', 'the', 'fact', 'that', 'it', "'s", 'real', '.', "They're", 'curious', 'about', 'the', 'war', 'in', 'Vietnam', 'after', '20', 'years', ',', "''", 'he', 'said', '.', 'While', 'Southeast', 'Asia', 'was', 'the', 'pivotal', 'foreign', 'issue', 'in', 'American', 'society', 'of', 'the', "'60s", ',', 'civil', 'rights', ...

# %% [markdown]
# What do you notice about the way word_tokenize splits the original text in comparison to our first tokenization?  Does it remove punctuation in the ways you'd expect? Are there things that you'd change?
#
# Your Answer:

# %% [markdown]
# ### Now let's normalize, remove stopwords and empty strings, and remove punctuation from tokens.

# %%
import string

# create list containing stopwords and punctuation tokens
useless_words = nltk.corpus.stopwords.words("english") + list(string.punctuation)

# create table to delete punctuation
punctTable = str.maketrans('','',string.punctuation)

# create list of cleaned docs
cleanDocText = []
# iterate on the headline tokens of each document headline
for doc in docsTextTokens:
    # create a list of cleaned headline tokens
    cleanText = []
    # iterate on tokens in the doc headline list
    for token in doc:
        #normalize
        token = token.lower()
        # if token is not a stopword or lone punct mark, remove punctuation add to clean list
        if token not in useless_words and token != '':
            token = token.translate(punctTable)
            cleanText.append(token)
    # add clean headline to 
    cleanDocText.append(cleanText)
    
# print the cleanDocs token lists
print(cleanDocText)
# Out:
# [['celluloid', 'torch', 'passed', 'new', 'generation', 'filmmakers', 'grew', '1960s', '', 'platoon', '', '', 'running', 'empty', '', '', '1969', '', '', 'mississippi', 'burning', '', 'among', 'movies', 'released', 'past', 'two', 'years', 'writers', 'directors', 'brought', 'experiences', 'turbulent', 'decade', 'screen', '', 'contemporaries', '60s', 'filmmakers', '80s', 's', 'natural', '', 'said', 'robert', 'friedman', 'senior', 'vice', 'president', 'worldwide', 'advertising', 'publicity', 'warner', 'bros', 'chris', 'gerolmo', 'wrote', 'screenplay', '', 'mississippi', 'burning', '', 'noted', 'sheer', 'passage', 'time', 'allowed', 'others', 'express', 'feelings', 'decade', '', 'distance', 'important', '', 'said', '', 'believe', 's', 'lot', 'thinking', 'time', 'america', 'general', '', 'vietnam', 'war', 'defining', 'experience', 'many', 'people', '60s', 'shattering', 'consensus', 'united', 'states', 'right', 'even', 'moral', 'duty', 'intervene', 'conflicts', 'around', 'world', 'even', 'today', 'politicians', 'talk', 'disparagingly', '', 'vietnam', 'syndrome', '', 'referring', 'country', 's', 'reluctance', 'use', 'military', 'force', 'settle', 'disputes', '', 'think', 'future', 'historians', 'talk', 'vietnam', 'one', 'near', 'destructions', 'american', 'society', '', 'said', 'urie', 'brofenbrenner', 'professor', 'sociology', 'cornell', 'university', '', 'world', 'war', 'ii', 'knew', 'fighting', 'vietnam', '', '', 'full', 'metal', 'jacket', '', '', 'gardens', 'stone', '', '', 'platoon', '', '', 'good', 'morning', 'vietnam', '', '', 'hamburger', 'hill', '', '', 'bat', '21', '', 'use', 'war', 'dramatic', 'backdrop', 'show', 'shaped', 'characters', 'lives', 'vietnam', 'war', 'remained', 'emotional', 'issue', 'united', 'states', 'veterans', 'struggled', 'come', 'terms', 'experiences', 'one', 'oliver', 'stone', 'wrote', 'directed', 'academy', 'award', 'winning', '', 'platoon', '', '', 'saw', 'platoon', 'eight', 'times', '', 'said', 'john', 'j', 'anderson', 'palm', 'beach', 'county', 'sheriff', 's', 'lieutenant', 'served', 'vietnam', '1966', '67', '', 'cried', 'first', 'time', 'saw', '', 'third', 'fourth', 'times', 'platoon', 'helped', 'understand', '', 'stone', 'based', '', 'platoon', '', 'experiences', 'grunt', 'said', 'film', 'brought', 'issues', 'yet', 'resolved', '', 'people', 'responding', 'fact', 's', 'real', 'theyre', 'curious', 'war', 'vietnam', '20', 'years', '', 'said', 'southeast', 'asia', 'pivotal', 'foreign', 'issue', 'american', 'society', '60s', 'civil', 'rights', 'major', 'domestic', 'issue', 'civil', 'rights', 'movement', 'reached', 'peak', '', 'freedom', 'summer', '', '1964', 'large', 'groups', 'volunteers', 'headed', 'south', 'help', 'register', 'black', 'voters', '', 'five', 'corners', '', 'movie', 'summer', '64', 'bronx', 'starring', 'jodie', 'foster', 'friend', 'played', 'tim', 'robbins', 'leaves', 'neighborhood', 'volunteer', 'south', 'seeing', 'rev', 'martin', 'luther', 'king', 'jr', 'television', 'alan', 'parker', 's', '', 'mississippi', 'burning', '', 'focuses', 'incident', 'clouded', 'mississippi', 'summer', 'project', '1000', 'young', 'volunteers', 'mainstream', 'america', 'swept', 'state', 'help', 'register', 'black', 'voters', 'movie', 'fictionalized', 'account', 'disappearance', 'slaying', 'three', 'civil', 'rights', 'workers', 'michael', 'schwerner', 'andrew', 'goodman', 'james', 'chaney', 'reported', 'missing', 'june', '21', 'several', 'hours', 'stopped', 'speeding', 'near', 'philadelphia', 'miss', 'nationally', 'publicized', 'search', 'bodies', 'discovered', 'aug', '4', 'farm', 'outside', 'town', 'one', 'recalled', 'incident', 'gerolmo', 'student', 'new', 'york', 'public', 'school', 'system', 'time', 'screenwriter', 'said', 'incident', 'powerful', 'effect', 'way', 'thinking', '', 'first', 'time', 'ever', 'considered', 'country', 'could', 'wrong', '', 'gerolmo', 'said', 'film', 'stars', 'willem', 'dafoe', 'gene', 'hackman', 'star', 'fbi', 'agents', 'try', 'find', 'bodies', 'missing', 'workers', 'overcome' ...

# %% [markdown]
# ### How do these tokens compare to the previous set?  Have the problems you saw before been addressed?

# %% [markdown]
# ### Now we have a list whose elements are themselves lists.  Each inner list contains the clean tokens from the headline of one document.  The next step is to stem the tokens so that words like 'run', 'runner', and 'running' all have the same representation.  Otherwise, if we query using the term 'running', the system won't search for documents that contain 'run' or 'runner'.

# %%
# import the stemmer
from nltk.stem import PorterStemmer
stemmer = PorterStemmer()
# ['illeg', 'firework', 'injur', 'hundr', 'peopl', 'ignit', 'six', 'fire', 'manila', 'leav', 'thousand', 'famili', 'homeless', 'new', 'year', 'polic', 'doctor', 'said', 'sunday', 'hospit', 'offici', 'said', 'seven', 'peopl', 'die', 'stray', 'bullet', 'stab', 'new', 'year', 's', 'celebr', 'brawl', 'manila', 'citi', 'cebu', '360', 'mile', 'southeast', 'manila', 'check', 'doctor', '20', 'govern', 'privat', 'hospit', 'capit', 'area', 'show', '1134', 'peopl', 'injur', 'mostli', 'firework', 'late', 'saturday', 'earli', 'sunday', '', 's', 'like', 'war', 'zone', '', 'said', 'govern', 'doctor', 'spoke', 'condit', 'anonym', '', 'finger', 'amput', 'peopl', 'wound', 'stray', 'bullet', 'still', 'come', 'record', 'still', 'shambl', 'last', 'night', '', 'fire', 'rage', 'one', 'slum', 'neighborhood', 'kill', 'least', 'one', 'person', 'destroy', '3000', 'makeshift', 'hous', 'said', 'arson', 'investig', 'cpl', 'edmar', 'espres', 'hundr', 'hous', 'apart', 'also', 'burn', 'five', 'fire', 'casualti', 'report', 'espres', 'said', '', 'fire', 'start', 'firecrack', '', 'espress', 'said', 'cebu', 'second', 'largest', 'citi', 'least', '86', 'peopl', 'sever', 'children', 'treat', 'govern', 'hospit', 'injuri', 'firecrack', 'bulacan', 'provinc', 'north', 'manila', '33', 'peopl', 'injur', 'frenzi', 'revelri', 'new', 'year', 's', 'eve', 'hospit', 'author', 'said', 'manufactur', 'sale', 'use', 'firecrack', 'illeg', 'philippin', 'ban', 'lightli', 'enforc', 'nation', 'peopl', 'tradit', 'explod', 'firework', 'usher', 'new', 'year', 'celebr', 'festiv', 'friday', 'us', 'serviceman', 'sgt', 'michael', 'kaleda', '29', 'florida', '10', 'year', 'old', 'filipino', 'boy', 'kill', 'homemad', 'firecrack', 'prematur', 'explod', 'american', 's', 'hous', 'outsid', 'clark', 'air', 'base', 'four', 'filipino', 'wound', 'blast', 'explos', 'thursday', 'clandestin', 'firecrack', 'factori', 'bulacan', 'provinc', 'kill', '11', 'peopl', 'injur', '20']

# %% [markdown]
# # Creating a Term-Document Matrix with TF-IDF weighting.
#
# #### Recall that term statistics tell us something about the word's importance or usefulness.  tf (term frequency) is the number of times a term occurs in a particular document.  tf measures 'aboutness' or tells us what a document is about.  idf (inverse document frequency) is the number of documents in which a term occurs.  idf measures the ability of the term to help distinguish between documents in the collection.  For example, if we have a collection of computer science papers, then it seems likely that the word 'compute' will be found in most documents.  So all documents look the same with respect to them containing the word 'compute'.  We can weight or measure the overall importance of a word in a document by scaling its tf by its idf or tf * idf.  If the word occurs frequently in the document, its tf component will be high.  However, if the document also occurs in many of the documents in the collection, the idf component will bring the overall weight down.
#
# ####
#
# ### Step 1.  To create a matrix, we first need to create a string of all tokens to represent each document.

# %%
# create a list of strings, each string consists of the normalized, stopped, stemmed terms for a doc's text 
tokensForVec = []
# iterate on the token list for each doc
count = 0
for stemmedTokens in stemmedDocTokens:
    # join the tokens into a string
    count += len(stemmedTokens)
    stemmedTokens = ' '.join(stemmedTokens)
    # append the string to the new list
    tokensForVec.append(stemmedTokens)
print(count)
print(tokensForVec)
# Out:
# 2558
#   (0, 69)	0.029089648405606277
#   (0, 696)	0.029089648405606277
#   (0, 124)	0.024146906375208853
#   (0, 631)	0.029089648405606277
#   (0, 1135)	0.029089648405606277
#   (0, 881)	0.058179296811212554
#   (0, 694)	0.029089648405606277
#   (0, 562)	0.029089648405606277
#   (0, 839)	0.029089648405606277
#   (0, 266)	0.024146906375208853
#   (0, 569)	0.029089648405606277
#   (0, 1000)	0.029089648405606277
#   (0, 414)	0.029089648405606277
#   (0, 204)	0.029089648405606277
#   (0, 847)	0.02063997509440447
#   (0, 1018)	0.02063997509440447
#   (0, 527)	0.029089648405606277
#   (0, 1062)	0.029089648405606277
#   :	:
#   (6, 803)	0.035781185545340134
#   (6, 365)	0.04121269649808292
#   (6, 94)	0.035781185545340134
#   (6, 782)	0.048215132007542745
#   (6, 742)	0.031343317962722606
#   (6, 954)	0.035781185545340134
#   (6, 891)	0.04121269649808292
#   (6, 702)	0.04121269649808292
#   (6, 748)	0.04121269649808292
#   (6, 644)	0.048215132007542745
#   (6, 463)	0.04121269649808292
#   (6, 1002)	0.048215132007542745
#   (6, 22)	0.08242539299616584
#   (6, 154)	0.04121269649808292
#   (6, 255)	0.035781185545340134
#   (6, 970)	0.035781185545340134
#   (6, 100)	0.04121269649808292
#   (6, 770)	0.06268663592544521
#   (6, 1129)	0.035781185545340134
#   (6, 798)	0.3297015719846634
#   (6, 1152)	0.04121269649808292
#   (6, 919)	0.19313808069469734
#   (6, 1191)	0.1379557719247838
#   (6, 189)	0.048215132007542745
#   (6, 751)	0.12537327185089042

# %% [markdown]
# ### How do we interpret the matrix above?  Note that each row begins with a tuple of the form (x,y) followed by a floating point value.  The tuple represents the document number and the feature (word) number. The last value in the row is the tf-idf weight of the word.  Lets print the list of features (words) and their indices.

# %%
for i, feature in enumerate(vectorizer.get_feature_names_out()):
    print(i, feature)
# Out:
# 0 10
# 1 1000
# 2 11
# 3 1134
# 4 12
# 5 120000
# 6 13th
# 7 14100
# 8 16
# 9 17
# 10 19
# 11 1960
# 12 1963
# 13 1964
# 14 1966
# 15 1969
# 16 1970
# 17 1986
# 18 1987
# 19 1988
# 20 1989
# 21 1990
# 22 20
# 23 200
# 24 21
# 25 22
# 26 23
# 27 287
# 28 29
# 29 30
# 30 3000
# 31 30000
# 32 33
# 33 34th
# 34 360
# 35 371
# 36 38
# 37 3800
# 38 39
# 39 46000
# 40 48
# 41 50
# 42 500000
# 43 53
# 44 55
# 45 55th
# 46 60
# 47 600
# 48 60000
# 49 600000
# 50 63
# 51 64
# 52 66th
# 53 67
# 54 70000
# 55 80
# 56 81
# 57 86
# 58 90
# 59 9mm
# 60 abil
# 61 abl
# 62 absenc
# 63 abstin
# 64 academi
# 65 accid
# 66 accident
# 67 accord
# 68 account
# 69 accur
# 70 across
# 71 act
# 72 activ
# 73 activist
# 74 ad
# 75 adaman
# 76 addict
# 77 advanc
# 78 advertis
# 79 affair
# 80 affect
# 81 agent
# 82 ager
# 83 aggress
# 84 ago
# 85 aid
# 86 air
# 87 aka
# 88 alan
# 89 alcohol
# 90 allow
# 91 almost
# 92 alptekin
# 93 alreadi
# 94 also
# 95 alter
# 96 although
# 97 aluminum
# 98 am
# 99 america
# 100 american
# 101 among
# 102 amput
# 103 analyz
# 104 anderson
# 105 andi
# 106 andrew
# 107 anheus
# 108 announc
# 109 annual
# 110 anonym
# 111 anoth
# 112 anti
# 113 apart
# 114 appetit
# 115 appreci
# 116 approach
# 117 appropri
# 118 area
# 119 arm
# 120 around
# 121 arrest
# 122 arriv
# 123 arson
# 124 art
# 125 artist
# 126 asia
# 127 ask
# 128 aspect
# 129 assign
# 130 associ
# 131 atlant
# 132 attend
# 133 attorney
# 134 aug
# 135 august
# 136 author
# 137 autom
# 138 automobil
# 139 avail
# 140 aviat
# 141 awar
# 142 award
# 143 away
# 144 backdrop
# 145 bailout
# 146 ball
# 147 ballroom
# 148 baltimor
# 149 ban
# 150 band
# 151 bank
# 152 barri
# 153 barrier
# 154 base
# 155 basketbal
# 156 bat
# 157 bate
# 158 battl
# 159 beach
# 160 becom
# 161 bedroom
# 162 believ
# 163 belt
# 164 benefit
# 165 best
# 166 betti
# 167 black
# 168 blame
# 169 blast
# 170 board
# 171 bob
# 172 bodi
# 173 borchelt
# 174 boston
# 175 boy
# 176 brawl
# 177 break
# 178 bro
# 179 broadway
# 180 brofenbrenn
# 181 bronx
# 182 brooklyn
# 183 brought
# 184 bucci
# 185 build
# 186 bulacan
# 187 bull
# 188 bullet
# 189 burn
# 190 burr
# 191 busch
# 192 bush
# 193 busi
# 194 ca
# 195 calib
# 196 california
# 197 call
# 198 caller
# 199 came
# 200 candid
# 201 capit
# 202 capita
# 203 capitol
# 204 carolina
# 205 carri
# 206 casino
# 207 casualti
# 208 caught
# 209 caus
# 210 cave
# 211 cc
# 212 cebu
# 213 celebr
# 214 celluloid
# 215 center
# 216 chain
# 217 chairman
# 218 champagn
# 219 chaney
# 220 charact
# 221 charlott
# 222 chatter
# 223 check
# 224 cheer
# 225 chemic
# 226 cherri
# 227 chief
# 228 children
# 229 chose
# 230 chri
# 231 christin
# 232 christma
# 233 circu
# 234 citi
# 235 citizen
# 236 civil
# 237 clack
# 238 clandestin
# 239 clark
# 240 class
# 241 claudia
# 242 clean
# 243 click
# 244 climb
# 245 clog
# 246 cloud
# 247 club
# 248 co
# 249 cocain
# 250 colleagu
# 251 colleg
# 252 colo
# 253 colorado
# 254 columbia
# 255 come
# 256 comment
# 257 common
# 258 commonli
# 259 commonplac
# 260 commun
# 261 compar
# 262 complain
# 263 complet
# 264 compon
# 265 comput
# 266 concern
# 267 condit
# 268 confer
# 269 conflict
# 270 conov
# 271 consensu
# 272 consid
# 273 consider
# 274 consult
# 275 contemporari
# 276 contest
# 277 continu
# 278 control
# 279 convey
# 280 coordin
# 281 corin
# 282 cornel
# 283 corner
# 284 corni
# 285 corp
# 286 cost
# 287 could
# 288 countdown
# 289 counti
# 290 countri
# 291 court
# 292 cpl
# 293 crack
# 294 creat
# 295 cri
# 296 crime
# 297 critic
# 298 culmin
# 299 cultur
# 300 curiou
# 301 current
# 302 cut
# 303 dafo
# 304 danc
# 305 dancer
# 306 danger
# 307 danni
# 308 dark
# 309 daughter
# 310 day
# 311 dealer
# 312 dec
# 313 decad
# 314 decid
# 315 decis
# 316 decreas
# 317 dedic
# 318 defin
# 319 democrat
# 320 denver
# 321 depart
# 322 depth
# 323 deriv
# 324 descend
# 325 design
# 326 destroy
# 327 destruct
# 328 determin
# 329 detroit
# 330 develop
# 331 devito
# 332 diagnos
# 333 die
# 334 diego
# 335 differ
# 336 difficult
# 337 dip
# 338 direct
# 339 director
# 340 disabl
# 341 disappear
# 342 discov
# 343 discuss
# 344 dispar
# 345 disparagingli
# 346 display
# 347 disput
# 348 distanc
# 349 district
# 350 doctor
# 351 domest
# 352 domin
# 353 done
# 354 downey
# 355 downtown
# 356 dramat
# 357 drawn
# 358 dreyfuss
# 359 drink
# 360 drive
# 361 dropout
# 362 drug
# 363 dubiou
# 364 duti
# 365 earli
# 366 earlier
# 367 earmark
# 368 earn
# 369 easili
# 370 econom
# 371 edg
# 372 edmar
# 373 educ
# 374 effect
# 375 effort
# 376 eight
# 377 elect
# 378 electr
# 379 eleph
# 380 elev
# 381 els
# 382 emot
# 383 empti
# 384 encount
# 385 encourag
# 386 end
# 387 enforc
# 388 engin
# 389 engrav
# 390 enhanc
# 391 enough
# 392 enrol
# 393 enter
# 394 entir
# 395 entrepreneur
# 396 equip
# 397 ernest
# 398 erron
# 399 escap
# 400 eschew
# 401 espres
# 402 espress
# 403 establish
# 404 estim
# 405 etess
# 406 eve
# 407 even
# 408 event
# 409 ever
# 410 everett
# 411 everi
# 412 everyon
# 413 evid
# 414 excit
# 415 execut
# 416 exist
# 417 expand
# 418 expect
# 419 experi
# 420 expertis
# 421 explod
# 422 explos
# 423 express
# 424 extra
# 425 eye
# 426 fact
# 427 faction
# 428 factori
# 429 fairground
# 430 fairli
# 431 famili
# 432 far
# 433 farm
# 434 fatal
# 435 fbi
# 436 fear
# 437 feder
# 438 feel
# 439 feet
# 440 festiv
# 441 fewer
# 442 fiction
# 443 field
# 444 fierc
# 445 fight
# 446 figur
# 447 filipino
# 448 film
# 449 filmmak
# 450 final
# 451 financi
# 452 find
# 453 fine
# 454 finger
# 455 finish
# 456 fire
# 457 firecrack
# 458 firefight
# 459 firework
# 460 firmli
# 461 first
# 462 fit
# 463 five
# 464 flagtown
# 465 flashi
# 466 float
# 467 florida
# 468 focus
# 469 foner
# 470 foot
# 471 forc
# 472 foreign
# 473 former
# 474 forward
# 475 foster
# 476 found
# 477 four
# 478 fourth
# 479 franci
# 480 fred
# 481 free
# 482 freedom
# 483 frenzi
# 484 frequent
# 485 friday
# 486 friedman
# 487 friend
# 488 front
# 489 fulcrum
# 490 full
# 491 futur
# 492 futurist
# 493 garcia
# 494 garden
# 495 gene
# 496 gener
# 497 georg
# 498 geriatr
# 499 gerolmo
# 500 get
# 501 giant
# 502 give
# 503 glass
# 504 glitz
# 505 go
# 506 good
# 507 goodman
# 508 got
# 509 govern
# 510 graduat
# 511 grand
# 512 grasp
# 513 grew
# 514 group
# 515 grow
# 516 growth
# 517 grunt
# 518 gun
# 519 guy
# 520 hackman
# 521 hairspray
# 522 half
# 523 hall
# 524 hamburg
# 525 handgun
# 526 happen
# 527 harlem
# 528 head
# 529 headach
# 530 heaven
# 531 help
# 532 high
# 533 higher
# 534 highest
# 535 highli
# 536 hiker
# 537 hill
# 538 hirsch
# 539 histor
# 540 historian
# 541 hold
# 542 holiday
# 543 home
# 544 homeless
# 545 homemad
# 546 homicid
# 547 honor
# 548 hope
# 549 hospit
# 550 hotel
# 551 hour
# 552 hous
# 553 howev
# 554 human
# 555 hundr
# 556 husband
# 557 ibm
# 558 identifi
# 559 ignit
# 560 ii
# 561 illeg
# 562 impact
# 563 import
# 564 incept
# 565 incid
# 566 increasingli
# 567 ind
# 568 indiana
# 569 indic
# 570 industri
# 571 infest
# 572 inform
# 573 infus
# 574 injur
# 575 injuri
# 576 insan
# 577 insid
# 578 insolv
# 579 inspector
# 580 inspir
# 581 instead
# 582 institut
# 583 instruct
# 584 integr
# 585 intern
# 586 interven
# 587 intric
# 588 inventori
# 589 investig
# 590 involv
# 591 iron
# 592 island
# 593 issu
# 594 jacket
# 595 jail
# 596 jam
# 597 jambore
# 598 jame
# 599 jay
# 600 jersey
# 601 jewish
# 602 jim
# 603 jodi
# 604 john
# 605 joint
# 606 joyc
# 607 jr
# 608 judd
# 609 june
# 610 justifi
# 611 kaleda
# 612 keep
# 613 keifer
# 614 kenni
# 615 key
# 616 kid
# 617 kill
# 618 killingsworth
# 619 kind
# 620 king
# 621 knew
# 622 know
# 623 knowledg
# 624 known
# 625 la
# 626 lab
# 627 laboratori
# 628 ladder
# 629 lahti
# 630 larg
# 631 larger
# 632 largest
# 633 larri
# 634 laser
# 635 last
# 636 late
# 637 lath
# 638 lavecchia
# 639 law
# 640 le
# 641 leader
# 642 learn
# 643 least
# 644 leav
# 645 leighton
# 646 less
# 647 letter
# 648 level
# 649 levinson
# 650 lieuten
# 651 lift
# 652 light
# 653 lightli
# 654 like
# 655 limit
# 656 line
# 657 link
# 658 listen
# 659 lit
# 660 littl
# 661 live
# 662 loan
# 663 local
# 664 lombardo
# 665 lot
# 666 love
# 667 luther
# 668 machin
# 669 machineri
# 670 made
# 671 mainstream
# 672 major
# 673 make
# 674 maker
# 675 makeshift
# 676 man
# 677 manag
# 678 mani
# 679 manila
# 680 manufactur
# 681 map
# 682 march
# 683 market
# 684 martin
# 685 martinsvil
# 686 master
# 687 materi
# 688 mauck
# 689 mauric
# 690 may
# 691 maze
# 692 mean
# 693 mechan
# 694 media
# 695 medic
# 696 medium
# 697 member
# 698 men
# 699 messag
# 700 metal
# 701 miami
# 702 michael
# 703 middl
# 704 midnight
# 705 mile
# 706 militari
# 707 mill
# 708 million
# 709 mind
# 710 miniatur
# 711 minor
# 712 minut
# 713 mirror
# 714 misbehav
# 715 miss
# 716 mississippi
# 717 missouri
# 718 mitchel
# 719 model
# 720 money
# 721 month
# 722 mora
# 723 moral
# 724 more
# 725 morgan
# 726 morn
# 727 mostli
# 728 motorist
# 729 mountaintop
# 730 move
# 731 movement
# 732 movi
# 733 mph
# 734 mr
# 735 ms
# 736 much
# 737 murder
# 738 music
# 739 naomi
# 740 napalm
# 741 narcot
# 742 nation
# 743 natur
# 744 nc
# 745 near
# 746 necessari
# 747 need
# 748 neighborhood
# 749 neon
# 750 never
# 751 new
# 752 newark
# 753 news
# 754 night
# 755 nj
# 756 north
# 757 northern
# 758 northwest
# 759 note
# 760 nt
# 761 number
# 762 ny
# 763 object
# 764 offbeat
# 765 offer
# 766 offic
# 767 offici
# 768 old
# 769 oliv
# 770 one
# 771 oper
# 772 opera
# 773 orang
# 774 orchestra
# 775 order
# 776 organ
# 777 origin
# 778 orlean
# 779 other
# 780 outclass
# 781 outrag
# 782 outsid
# 783 outstand
# 784 overcom
# 785 overcrowd
# 786 packag
# 787 palm
# 788 parad
# 789 parent
# 790 parker
# 791 part
# 792 parti
# 793 particularli
# 794 pass
# 795 passag
# 796 past
# 797 peak
# 798 peopl
# 799 per
# 800 percent
# 801 percept
# 802 perform
# 803 person
# 804 phantom
# 805 philadelphia
# 806 philippin
# 807 pike
# 808 pivot
# 809 place
# 810 plan
# 811 plant
# 812 plastic
# 813 platoon
# 814 play
# 815 plaza
# 816 pledg
# 817 plexiglass
# 818 pm
# 819 pole
# 820 polic
# 821 polici
# 822 polit
# 823 politician
# 824 popul
# 825 posit
# 826 pound
# 827 power
# 828 practic
# 829 prais
# 830 predict
# 831 prematur
# 832 present
# 833 presid
# 834 press
# 835 prevail
# 836 prevent
# 837 previou
# 838 price
# 839 principl
# 840 privat
# 841 problem
# 842 procastin
# 843 process
# 844 produc
# 845 product
# 846 professor
# 847 program
# 848 project
# 849 promot
# 850 prosecut
# 851 prosecutor
# 852 provinc
# 853 public
# 854 purchas
# 855 push
# 856 put
# 857 puzzl
# 858 quail
# 859 qualifi
# 860 qualiti
# 861 question
# 862 quit
# 863 radic
# 864 rage
# 865 raid
# 866 rang
# 867 rate
# 868 raw
# 869 ray
# 870 raymond
# 871 re
# 872 reach
# 873 react
# 874 real
# 875 recal
# 876 recent
# 877 recogn
# 878 record
# 879 reduc
# 880 refer
# 881 reflect
# 882 region
# 883 regist
# 884 rel
# 885 relat
# 886 releas
# 887 reload
# 888 reluct
# 889 remain
# 890 replac
# 891 report
# 892 rescu
# 893 resid
# 894 resist
# 895 resolut
# 896 resolv
# 897 respond
# 898 respons
# 899 result
# 900 retriev
# 901 rev
# 902 revel
# 903 revelri
# 904 revolv
# 905 richard
# 906 ride
# 907 right
# 908 robbin
# 909 robert
# 910 robot
# 911 role
# 912 rolla
# 913 roof
# 914 room
# 915 run
# 916 russel
# 917 ruttan
# 918 sabatog
# 919 said
# 920 sale
# 921 salesmen
# 922 san
# 923 sasser
# 924 sate
# 925 saturday
# 926 save
# 927 saw
# 928 say
# 929 schedul
# 930 school
# 931 schwerner
# 932 screen
# 933 screenplay
# 934 screenwrit
# 935 search
# 936 seat
# 937 second
# 938 see
# 939 segreg
# 940 seizur
# 941 sell
# 942 sema
# 943 semiautomat
# 944 sen
# 945 send
# 946 senior
# 947 sentri
# 948 seriou
# 949 serv
# 950 serviceman
# 951 set
# 952 settl
# 953 seven
# 954 sever
# 955 sex
# 956 sgt
# 957 shambl
# 958 shape
# 959 shatter
# 960 sheer
# 961 shelf
# 962 shelv
# 963 sheraton
# 964 sheriff
# 965 shoot
# 966 shop
# 967 short
# 968 shortag
# 969 shot
# 970 show
# 971 si
# 972 side
# 973 silent
# 974 similar
# 975 simpli
# 976 sinc
# 977 site
# 978 six
# 979 size
# 980 skill
# 981 skyward
# 982 slain
# 983 slay
# 984 slick
# 985 slum
# 986 small
# 987 snow
# 988 snowcap
# 989 societi
# 990 sociolog
# 991 sociologist
# 992 softwar
# 993 sole
# 994 solitari
# 995 solv
# 996 somehow
# 997 someth
# 998 son
# 999 sophist
# 1000 sorri
# 1001 south
# 1002 southeast
# 1003 specif
# 1004 speed
# 1005 spend
# 1006 spent
# 1007 spoke
# 1008 spokesman
# 1009 spree
# 1010 spring
# 1011 squalid
# 1012 squar
# 1013 st
# 1014 stab
# 1015 standard
# 1016 star
# 1017 starburst
# 1018 start
# 1019 state
# 1020 statu
# 1021 stay
# 1022 stem
# 1023 step
# 1024 stephen
# 1025 stepper
# 1026 still
# 1027 stone
# 1028 stop
# 1029 storag
# 1030 stori
# 1031 stray
# 1032 street
# 1033 strong
# 1034 struggl
# 1035 student
# 1036 studi
# 1037 submachin
# 1038 sue
# 1039 suit
# 1040 summer
# 1041 sunday
# 1042 suppli
# 1043 sure
# 1044 surpass
# 1045 survey
# 1046 surviv
# 1047 susan
# 1048 suspect
# 1049 sutherland
# 1050 swarm
# 1051 sweep
# 1052 sweetest
# 1053 swept
# 1054 swing
# 1055 switch
# 1056 swivel
# 1057 syndrom
# 1058 system
# 1059 take
# 1060 talk
# 1061 task
# 1062 taught
# 1063 taxi
# 1064 teamwork
# 1065 teen
# 1066 televis
# 1067 temperatur
# 1068 tenn
# 1069 term
# 1070 texa
# 1071 theme
# 1072 theyr
# 1073 thigh
# 1074 think
# 1075 third
# 1076 thompson
# 1077 thousand
# 1078 three
# 1079 thursday
# 1080 tide
# 1081 tie
# 1082 tilda
# 1083 tim
# 1084 time
# 1085 timothi
# 1086 tin
# 1087 toast
# 1088 today
# 1089 tom
# 1090 tomorrow
# 1091 top
# 1092 torch
# 1093 total
# 1094 tough
# 1095 tourist
# 1096 tout
# 1097 town
# 1098 tradit
# 1099 traffic
# 1100 train
# 1101 trap
# 1102 treat
# 1103 treatment
# 1104 tree
# 1105 trek
# 1106 trend
# 1107 tri
# 1108 trooper
# 1109 true
# 1110 trump
# 1111 truth
# 1112 tuck
# 1113 tune
# 1114 turbul
# 1115 turf
# 1116 turn
# 1117 turner
# 1118 tv
# 1119 two
# 1120 type
# 1121 underground
# 1122 understand
# 1123 uniqu
# 1124 unit
# 1125 univers
# 1126 upgrad
# 1127 uri
# 1128 us
# 1129 use
# 1130 usher
# 1131 usual
# 1132 uzi
# 1133 vacat
# 1134 valri
# 1135 valu
# 1136 varieti
# 1137 ve
# 1138 veteran
# 1139 vice
# 1140 viciou
# 1141 vietnam
# 1142 vision
# 1143 visit
# 1144 volunt
# 1145 voter
# 1146 waa
# 1147 waist
# 1148 wait
# 1149 wall
# 1150 wander
# 1151 want
# 1152 war
# 1153 warner
# 1154 washington
# 1155 washingtonian
# 1156 watch
# 1157 water
# 1158 way
# 1159 weapon
# 1160 weaponri
# 1161 week
# 1162 well
# 1163 wendt
# 1164 went
# 1165 west
# 1166 white
# 1167 wichita
# 1168 widespread
# 1169 wild
# 1170 willem
# 1171 william
# 1172 willing
# 1173 win
# 1174 wind
# 1175 wirth
# 1176 without
# 1177 woman
# 1178 work
# 1179 worker
# 1180 workplac
# 1181 world
# 1182 worldwid
# 1183 would
# 1184 wound
# 1185 write
# 1186 writer
# 1187 written
# 1188 wrong
# 1189 wrote
# 1190 wrought
# 1191 year
# 1192 yet
# 1193 york
# 1194 young
# 1195 youth
# 1196 zero
# 1197 zone
# 1198 zuniga

# %% [markdown]
# #### Notice that for document 6, the word 'also' (index 94) has a lower weight than the word 'american' (index 100).

# %% [markdown]
# ### Now lets transpose our matrix and create a dataframe.  In the table displayed, each row corresponds to a word and each column to a document.  If the word in a row occurs in the document in the column, then the cell entry will be a non-zero tf-idf weight.

# %%
#Convert the matrix as a transposed matrix
matrix = matrix.T.toarray()

#create a DataFrame and set the vocabulary as the index
dframe = pd.DataFrame(matrix, index=vectorizer.get_feature_names_out())

display(dframe)
# Out:
#                0         1    2         3    4         5         6
# 10      0.000000  0.000000  0.0  0.029307  0.0  0.000000  0.048215
# 1000    0.024147  0.000000  0.0  0.000000  0.0  0.088119  0.000000
# 11      0.000000  0.000000  0.0  0.000000  0.0  0.000000  0.058085
# 1134    0.000000  0.000000  0.0  0.000000  0.0  0.000000  0.058085
# 12      0.000000  0.026471  0.0  0.000000  0.0  0.000000  0.000000
# ...          ...       ...  ...       ...  ...       ...       ...
# young   0.041280  0.018782  0.0  0.050101  0.0  0.000000  0.000000
# youth   0.029090  0.000000  0.0  0.000000  0.0  0.000000  0.000000
# zero    0.000000  0.000000  0.0  0.000000  0.0  0.035385  0.000000
# zone    0.000000  0.000000  0.0  0.000000  0.0  0.000000  0.058085
# zuniga  0.000000  0.000000  0.0  0.000000  0.0  0.035385  0.000000
#
# [1199 rows x 7 columns]

# %% [markdown]
# # Calculating the similarity of a query and a document

# %% [markdown]
# #### We represent our documents as vectors in a multidimensional space.  In this space, each word is a dimension.  Documents that are more similar will tend to point in the same direction.  We can measure how similar one vector is to another by measuring the cosine of the angle between the vectors.  If the vectors point in exactly the same direction, the cosine will be zero.  We measure To determine which documents are similar to a query, we generate a vector for the query in our vector space.
#
# ## Steps to find similarities between a query and our documents
#
# #### 1) convert the query to a vector
# #### 2) caclualte the similarity of the query to the documents
# #### 3) sort the similarity scores
# #### 4) display the documents and their scores

# %%
import numpy as np
# function to search for articles that are similar
# q is the query, df is the dataframe, corpus is the list of document strings
def evaluate_query (q, df, corpus):
    #convert query to vector
    q = [q]
    # transform the query to a matrix, get its dimensions, the reshape it to be a 1 x v vector, 
    # where v is the size of (number of terms in) the collection
    q_vec = vectorizer.transform(q).toarray().reshape(df.shape[0],)
    # dictionary of similar documents
    sim = {}
    
    # calculate the similarity
    # we have 5 documents in the collection
    for i in range(5):
        sim[i] = np.dot(df.loc[:, i].values, q_vec) / np.linalg.norm(df.loc[:, i]) * np.linalg.norm(q_vec)
        
    # sort the similarity values
    # the items method returns a list of (key, value) tuples. The sim dictionary will be sorted
    # the lambda function sets the key for the sort to the value of each tuple, 
    # and it sorts them in descending order
    sim_sorted = sorted(sim.items(), key=lambda x: x[1], reverse=True)
    
    # print the documents and their similarity scores
    for k, v, in sim_sorted:
        if v != 0.0:
            print("similarity:",v)
            print("stemmed doc:", tokensForVec[k])
            print("doc: ",corpus[k])

# %%
# create a query
myQ = "filmmakers and films"

# process the query in the same way that the documents were processed
# this is already normalized so we remove stopwords and stem
qTokens = nltk.word_tokenize(myQ)
stemmedTokens = []
for word in qTokens:
    if word not in useless_words:
        word = stemmer.stem(word)
        stemmedTokens.append(word)
stemmedQ = ' '.join(stemmedTokens)
print(stemmedQ)
# Out:
# filmmak film

# %%
#invoke the function that calculates similarity
evaluate_query(stemmedQ,dframe,docTexts)
# Out:
# similarity: 0.14398641354955646
# stemmed doc: celluloid torch pass new gener filmmak grew 1960  platoon   run empti   1969   mississippi burn  among movi releas past two year writer director brought experi turbul decad screen  contemporari 60 filmmak 80 s natur  said robert friedman senior vice presid worldwid advertis public warner bro chri gerolmo wrote screenplay  mississippi burn  note sheer passag time allow other express feel decad  distanc import  said  believ s lot think time america gener  vietnam war defin experi mani peopl 60 shatter consensu unit state right even moral duti interven conflict around world even today politician talk disparagingli  vietnam syndrom  refer countri s reluct use militari forc settl disput  think futur historian talk vietnam one near destruct american societi  said uri brofenbrenn professor sociolog cornel univers  world war ii knew fight vietnam   full metal jacket   garden stone   platoon   good morn vietnam   hamburg hill   bat 21  use war dramat backdrop show shape charact live vietnam war remain emot issu unit state veteran struggl come term experi one oliv stone wrote direct academi award win  platoon   saw platoon eight time  said john j anderson palm beach counti sheriff s lieuten serv vietnam 1966 67  cri first time saw  third fourth time platoon help understand  stone base  platoon  experi grunt said film brought issu yet resolv  peopl respond fact s real theyr curiou war vietnam 20 year  said southeast asia pivot foreign issu american societi 60 civil right major domest issu civil right movement reach peak  freedom summer  1964 larg group volunt head south help regist black voter  five corner  movi summer 64 bronx star jodi foster friend play tim robbin leav neighborhood volunt south see rev martin luther king jr televis alan parker s  mississippi burn  focus incid cloud mississippi summer project 1000 young volunt mainstream america swept state help regist black voter movi fiction account disappear slay three civil right worker michael schwerner andrew goodman jame chaney report miss june 21 sever hour stop speed near philadelphia miss nation public search bodi discov aug 4 farm outsid town one recal incid gerolmo student new york public school system time screenwrit said incid power effect way think  first time ever consid countri could wrong  gerolmo said film star willem dafo gene hackman star fbi agent tri find bodi miss worker overcom fierc local resist solv crime offbeat outrag way john water  hairspray  discuss integr baltimor 1963 group teen ager tri break barrier segreg danc show also set baltimor barri levinson s  tin men  star danni devito richard dreyfuss two slick aluminum side salesmen earli 60 movi mirror squar middl class cultur one caught sex polit drug instead focus well known histor event writer director ernest thompson take person approach  1969  robert downey jr keifer sutherland star colleg student battl parent sex drug vietnam war  19 1969 fulcrum time  said thompson student american univers time  think right time growth artist man tri write someth happen youth   run empti  take place 80 60 much evid judd hirsch christin lahti play anti war activist sabatog napalm plant 1970 forc live underground two children naomi foner wrote  run empti  also serv film s execut produc grew brooklyn ny daughter sociologist experi made foner well qualifi give  run empti  strong polit theme  live time ve want find right way present gener  said foner member radic student democrat societi attend graduat school columbia univers foner also taught harlem s head start program help regist voter south carolina said mani young peopl curiou happen 60  lot think excit time sorri miss  said brofenbrenn said movi good indic concern gener public  principl impact media reflect valu larger societi  film power art medium  said  believ accur reflect prevail come trend s film writer like writer percept peopl get messag s go
# doc:
#    The celluloid torch has been passed to a new
# generation: filmmakers who grew up in the 1960s.
#    ``Platoon,'' ``Running on Empty,'' ``1969'' and ``Mississippi
# Burning'' are among the movies released in the past two years from
# writers and directors who brought their own experiences of that
# turbulent decade to the screen.
#    ``The contemporaries of the '60s are some of the filmmakers of
# the '80s. It's natural,'' said Robert Friedman, the senior vice
# president of worldwide advertising and publicity at Warner Bros.
#    Chris Gerolmo, who wrote the screenplay for ``Mississippi
# Burning,'' noted that the sheer passage of time has allowed him and
# others to express their feelings about the decade.
#    ``Distance is important,'' he said. ``I believe there's a lot of
# thinking about that time and America in general.''
#    The Vietnam War was a defining experience for many people in the
# '60s, shattering the consensus that the United States had a right,
# even a moral duty to intervene in conflicts around the world. Even
# today, politicians talk disparagingly of the ``Vietnam Syndrome'' in
# referring to the country's reluctance to use military force to
# settle disputes.
#    ``I think future historians will talk about Vietnam as one of the
# near destructions of American society,'' said Urie Brofenbrenner, a
# professor of sociology at Cornell University.
#    ``In World War II, we knew what we were fighting for, but not in
# Vietnam.''
#    ``Full Metal Jacket,'' ``Gardens of Stone,'' ``Platoon,'' ``Good
# Morning, Vietnam,'' ``Hamburger Hill'' and ``Bat 21'' all use the
# war as a dramatic backdrop and show how it shaped characters' lives.
#    The Vietnam War has remained an emotional issue in the United
# States as veterans have struggled to come to terms with their
# experiences. One was Oliver Stone, who wrote and directed the
# Academy Award winning ``Platoon.''
#    ``I saw `Platoon' eight times,'' said John J. Anderson, a Palm
# Beach County sheriff's lieutenant who served in Vietnam in 1966 67.
# ``I cried the first time I saw it ... and the third and fourth
# times. `Platoon' helped me understand.''
#    Stone, who based ``Platoon'' on some of his own experiences as a
# grunt, said the film brought up issues that had yet to be resolved.
#    ``People are responding to the fact that it's real. They're
# curious about the war in Vietnam after 20 years,'' he said.
#    While Southeast Asia was the pivotal foreign issue in American
# society of the '60s, civil rights was the major domestic issue. The
# civil rights movement reached its peak in the ``Freedom Summer'' of
# 1964, when large groups of volunteers headed South to help register
# black voters.
#    In ``Five Corners,'' a movie about the summer of '64 in the Bronx
# starring Jodie Foster, her friend, played by Tim Robbins, leaves his
# neighborhood to volunteer in the South after seeing the Rev. Martin
# Luther King Jr. on television.
#    Alan Parker's ``Mississippi Burning'' focuses on an incident that
# clouded the Mississippi Summer Project _ when 1,000 young volunteers
# from mainstream America swept into the state to help register black
# voters. The movie is a fictionalized account of the disappearance
# and slaying of three civil rights workers: Michael Schwerner, Andrew
# Goodman and James Chaney.
#    They were reported missing on June 21, several hours after being
# stopped for speeding near Philadelphia, Miss. After a nationally
# publicized search, their bodies were discovered Aug. 4 on a farm
# just outside the town.
#    One of those who recalled the incident was Gerolmo, a student in
# the New York public school system at the time. The screenwriter said
# the incident had a powerful effect on his way of thinking.
#    ``It was the first time I ever considered that our country could
# be wrong,'' Gerolmo said.
#    The film stars Willem Dafoe and Gene Hackman star as FBI agents
# who try to find the bodies of the missing workers and overcome
# fierce local resistance to solve the crime.
#    In a more offbeat and outrageous way, John Waters' ``Hairspray''
# discusses integration in Baltimore in 1963 when a group of
# teen agers tries to break down the barriers of a segregated dance
# show.
#    Also set in Baltimore is Barry Levinson's ``Tin Men,'' starring
# Danny DeVito and Richard Dreyfuss as two slick aluminum siding
# salesmen in the early '60s. The movie mirrored a squarely
# middle class culture, one that was not caught up in sex, politics
# and drugs.
#    Instead of focusing on a well known historic event,
# writer director Ernest Thompson takes a more personal approach in
# ``1969.'' Robert Downey Jr. and Keifer Sutherland star as college
# students who battle their parents and each other over sex, drugs and
# the Vietnam War.
#    ``I was 19 in 1969. It was a fulcrum time for me,'' said
# Thompson, who was a student at American University at the time. ``I
# think it was just the right time in my growth as an artist and as a
# man to try to write about something that happened in my youth.''
#    ``Running on Empty'' takes place in the '80s but the '60s are
# much in evidence. Judd Hirsch and Christine Lahti play anti war
# activists who sabatoged a napalm plant in 1970 and are forced to
# live underground with their two children.
#    Naomi Foner, who wrote ``Running on Empty'' and also served as
# the film's executive producer, grew up in Brooklyn, N.Y., the
# daughter of sociologists. Her own experiences made Foner well
# qualified to give ``Running on Empty'' its strong political theme.
#    ``I lived through that time and I've wanted to find the right way
# to present it to this generation,'' said Foner, a member of the
# radical Students for a Democratic Society while attending graduate
# school at Columbia University.
#    Foner, who also taught in Harlem's Head Start program and helped
# register voters in South Carolina, said many young people are
# curious about what happened in the '60s.
#    ``A lot of them think it was an exciting time that they were
# sorry to have missed,'' she said.
#    Brofenbrenner said movies are a good indicator of the concerns of
# the general public: ``The principle impact of the media is that they
# reflect the values of the larger society.
#    ``Film is a very powerful art medium,'' he said. ``I believe it
# very accurately reflects not only the prevailing but the coming
# trends. It's because film writers, like other writers, are
# perceptive people. They get the message of what's going on.''

# %% [markdown]
# ### Here you have a basic search engine.  Now use what you have learned to do the following:
# #### 1) collect the text from the 'text' nodes of the parsetree (soup from cell 1)
# #### 2) tokenize and process the text
# #### 3) build a tf-idf term-document matrix
# #### 4) Based on the contents of the documents (use less to view the original document file), come up with a couple of queries and evaluate them against your database.
# #### 5) print out the original documents and their similarity scores

# %% [markdown]
# ### If you have tested your code and can successfully build a matrix for the sample documents and then retrieve the top docs in response to a query, try to do the same with the larger collection in the shared folder, ap89.txt.
#
# Here are some queries you can test with the large collection:
#
# q1 =
# Black Resistance Against the South African Government.  Efforts by the
# black majority in South Africa to overthrow domination by the white
# minority government.
#
# q2 =
# Nuclear Proliferation.  Efforts by the United Nations or those nations
# currently possessing nuclear weapons to control the proliferation of
# nuclear weapons capabilities to the non-nuclear weapons states.
#
# q3 =
# Impact of the 1986 Immigration Law. Specific consequence(s) of the
# U.S.'s Immigration Reform and Control Act of 1986.
#
# q4 =
# International Terrorists.  Provide background information on
# international terrorist groups or individuals, or detail the
# activities of such groups or individuals.
#
# q5 =
# Actions Against International Terrorists.  Report activities by
# established political authorities against international terrorists.
